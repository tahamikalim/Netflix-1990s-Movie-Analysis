# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
netflix_data = pd.read_csv("netflix_data.csv")

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %%
netflix_movies = netflix_data[netflix_data["type"] == "Movie"]

# %%
netflix_movies.head()
# Out:
#   show_id   type  title           director  \
# 0      s2  Movie   7:19  Jorge Michel Grau
# 1      s3  Movie  23:59       Gilbert Chan
# 2      s4  Movie      9        Shane Acker
# 3      s5  Movie     21     Robert Luketic
# 5      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 5       June 1, 2020          2019        95
#
# ...

# %%
netflix_moviesdfs = netflix_movies[netflix_movies["release_year"] > 1990]

# %%
netflix_moviesdfs.head()
# Out:
#   show_id   type  title           director  \
# 0      s2  Movie   7:19  Jorge Michel Grau
# 1      s3  Movie  23:59       Gilbert Chan
# 2      s4  Movie      9        Shane Acker
# 3      s5  Movie     21     Robert Luketic
# 5      s7  Movie    122    Yasir Al Yasiri
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 5       June 1, 2020          2019        95
#
# ...

# %%
netflix_dffinal = netflix_moviesdfs[netflix_moviesdfs["release_year"] < 2000]

# %%
netflix_dffinal.head()
# Out:
#     show_id   type                            title            director  \
# 6        s8  Movie                              187      Kevin Reynolds
# 118    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 145    s211  Movie           A Night at the Roxbury    John Fortenberry
# 167    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 194    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 6    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 118  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 145  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 167  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 194  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 6    November 1, 2019          1997       119
# ...

# %%
plt.hist(netflix_dffinal["duration"])
plt.title("Distribution of the Movie Durations in the 1990s")
plt.xlabel("Duration (mins)")
plt.ylabel("Number of Movies")
plt.show()

# %%
netflix_dfshortaction = netflix_dffinal[netflix_dffinal["genre"] == "Action"]

# %%
netflix_dfshortaction.head()
# Out:
#     show_id   type                                  title           director  \
# 352    s508  Movie                        Andaz Apna Apna  Rajkumar Santoshi
# 431    s628  Movie  Austin Powers: The Spy Who Shagged Me          Jay Roach
# 468    s688  Movie                               Bad Boys        Michael Bay
# 515    s757  Movie                                Barsaat  Rajkumar Santoshi
# 675   s1003  Movie                            Blue Streak       Les Mayfield
#
#                                                   cast        country  \
# 352  Aamir Khan, Salman Khan, Raveena Tandon, Karis...          India
# 431  Mike Myers, Heather Graham, Michael York, Robe...  United States
# 468  Will Smith, Martin Lawrence, Téa Leoni, Tchéky...  United States
# 515  Twinkle Khanna, Bobby Deol, Danny Denzongpa, R...          India
# 675  Martin Lawrence, Luke Wilson, Peter Greene, Da...        Germany
#
#            date_added  release_year  duration  \
# ...

# %%
short_movie_count = 0

# %%
for label, row in netflix_dfshortaction.iterrows():
    if row["duration"] < 90:
        short_movie_count = short_movie_count + 1
    else:
        short_movie_count = short_movie_count
print(short_movie_count)
# Out:
# 6

# %%
shortmovie = (netflix_dfshortaction["duration"] < 90).sum()

# %%
print(shortmovie)
# Out:
# 6

# %% [markdown]
# ## Datacamp Solution:

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# Subset the DataFrame for type "Movie"
netflix_subset = netflix_df[netflix_df["type"] == "Movie"]

# Filter the to keep only movies released in the 1990s
# Start by filtering out movies that were released before 1990
subset = netflix_subset[(netflix_subset["release_year"] >= 1990)]

# And then do the same to filter out movies released on or after 2000
movies_1990s = subset[(subset["release_year"] < 2000)]

# Another way to do this step is to use the & operator which allows you to do this type of filtering in one step
# movies_1990s = netflix_subset[(netflix_subset["release_year"] >= 1990) & (netflix_subset["release_year"] < 2000)]

# Visualize the duration column of your filtered data to see the distribution of movie durations
# See which bar is the highest and save the duration value, this doesn't need to be exact!
plt.hist(movies_1990s["duration"])
plt.title('Distribution of Movie Durations in the 1990s')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.show()

duration = 100

# Filter the data again to keep only the Action movies
action_movies_1990s = movies_1990s[movies_1990s["genre"] == "Action"]

# Use a for loop and a counter to count how many short action movies there were in the 1990s

# Start the counter
short_movie_count111 = 0

# Iterate over the labels and rows of the DataFrame and check if the duration is less than 90, if it is, add 1 to the counter, if it isn't, the counter should remain the same
for label, row in action_movies_1990s.iterrows() :
    if row["duration"] < 90 :
        short_movie_count111 = short_movie_count111 + 1
    else:
        short_movie_count111 = short_movie_count111

print(short_movie_count111)

# A quicker way of counting values in a column is to use .sum() on the desired column
# (action_movies_1990s["duration"] < 90).sum()
# Out:
# 7

# %% [markdown]
# ## Again solving self

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
netflix11 = pd.read_csv("netflix_data.csv")

# %%
netflix11.head()
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %%
netflix111 = netflix11[netflix11["type"] == "Movie"]

# %%
netflix222 = netflix11[netflix11["release_year"] < 2000]

# %%
netflix333 = netflix222[netflix222["release_year"] >= 1990]

# %%
netflix333.head()
# Out:
#     show_id   type                            title            director  \
# 6        s8  Movie                              187      Kevin Reynolds
# 118    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 145    s211  Movie           A Night at the Roxbury    John Fortenberry
# 167    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 194    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 6    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 118  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 145  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 167  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 194  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 6    November 1, 2019          1997       119
# ...

# %%
plt.hist(netflix333["duration"], color = "blue", edgecolor = "red")
plt.title("Distribution of Movie Durations in the 1990s")
plt.xlabel("Duration in minutes")
plt.ylabel("Number of Movies")
plt.show()

# %%
duration = 100

# %%
netflix444 = netflix333[netflix333["genre"] == "Action"]

# %%
short_movie_count = 0
for label, row in netflix444.iterrows():
    if row["duration"] < 90:
        short_movie_count = short_movie_count + 1
    else:
        short_movie_count = short_movie_count
    
print(short_movie_count)
# Out:
# 7

# %%
short_movie_count = (netflix444["duration"] < 90).sum()

# %%
print(short_movie_count)
# Out:
# 7
